# %%
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point



data = pd.read_csv(r'C:\Users\kritan\Downloads\ShapeFiles\Nepal15.csv',)
nepaldata = gpd.read_file(r'C:\Users\kritan\Downloads\ShapeFiles\local_unit.shp')

# %%
M = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

for element in data:
    e = element.split(',')
date = [M[int(e[0].split('-')[1])-10]]
data1 = [e[1]]
Lati = [e[2]]
Longi = [e[3]]
data2 = [e[4]]
kA = [e[5]]
mn = [int(e[0].split('-')[1])]

for i in range(0,1481694):
    val = data.loc[i][0].split(',')
    date.append(M[int(val[0].split('-')[1])-1])
    data1.append(val[1])
    Lati.append(val[2])
    Longi.append(val[3])
    data2.append(val[4])
    kA.append(val[5])
    mn.append(int(val[0].split('-')[1]))

# %%
Lightning_data = {
    'Month':date,
    'Month.no':mn,
    'Data1':data1,
    'Latitude':Lati,
    'Longitude':Longi,
    'data2':data2,
    'KA_':kA
    
    }

LightningDf = pd.DataFrame(Lightning_data)
LightningDf.to_csv(r'C:\Users\kritan\Downloads\ShapeFiles\LightningData.csv', index = False)




geometry = [Point(xy) for xy in zip(LightningDf['Longitude'],LightningDf['Latitude'])]
points_of_interest = gpd.GeoDataFrame(LightningDf, geometry = geometry, crs = nepaldata.crs)

points_of_interest_in_nepal = gpd.sjoin(points_of_interest, nepaldata, how='inner', op = 'within')
# Out:
# D:\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3445: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# <bound method NDFrame.head of             Month  Month.no         Data1 Latitude Longitude  data2 KA_  \
# 0           April         1  06:24:39.131   30.000    81.930  -34.1  kA
# 1         January         1  06:37:41.584   28.917    81.246  +92.9  kA
# 2         January         1  06:37:41.603   28.968    81.264  -17.6  kA
# 3         January         1  06:37:41.630   28.964    81.231  -17.0  kA
# 4         January         1  06:37:41.657   28.958    81.245  -11.9  kA
# ...           ...       ...           ...      ...       ...    ...  ..
# 1481690  December        12  11:45:48.090   27.396    87.243  +23.3  kA
# 1481691  December        12  11:45:48.105   27.387    87.253   +8.6  kA
# 1481692  December        12  11:46:16.108   27.247    87.626   -7.8  kA
# 1481693  December        12  11:48:54.091   27.404    87.224  +19.8  kA
# 1481694  December        12  11:48:54.100   27.396    87.234  +12.0  kA
#
#                           geometry
# 0        POINT (81.93000 30.00000)
# 1        POINT (81.24600 28.91700)
# 2        POINT (81.26400 28.96800)
# 3        POINT (81.23100 28.96400)
# 4        POINT (81.24500 28.95800)
# ...                            ...
# 1481690  POINT (87.24300 27.39600)
# 1481691  POINT (87.25300 27.38700)
# 1481692  POINT (87.62600 27.24700)
# 1481693  POINT (87.22400 27.40400)
# 1481694  POINT (87.23400 27.39600)
#
# [1481695 rows x 8 columns]>
# <bound method NDFrame.head of             Month  Month.no         Data1 Latitude Longitude  data2 KA_  \
# 0           April         1  06:24:39.131   30.000    81.930  -34.1  kA
# 651       January         1  17:43:10.238   30.049    81.939   +8.1  kA
# 668       January         1  18:01:28.203   30.033    81.864   +8.2  kA
# 38137    February         2  14:02:42.418   29.932    81.739   -9.2  kA
# 38146    February         2  14:04:51.717   29.929    81.766   -6.3  kA
# ...           ...       ...           ...      ...       ...    ...  ..
# 1295957    August         8  16:58:29.268   29.273    84.017  -14.5  kA
# 1295958    August         8  16:58:29.299   29.229    84.047   -7.3  kA
# 1297070    August         8  18:05:02.354   29.237    83.926  +26.6  kA
# 1297138    August         8  18:10:18.969   29.209    83.923   -9.6  kA
# 1305378    August         8  10:23:49.546   29.262    83.835  -15.1  kA
#
#                           geometry  index_right  STATE_CODE DISTRICT  \
# 0        POINT (81.93000 30.00000)          668           6    HUMLA
# 651      POINT (81.93900 30.04900)          668           6    HUMLA
# 668      POINT (81.86400 30.03300)          668           6    HUMLA
# 38137    POINT (81.73900 29.93200)          668           6    HUMLA
# 38146    POINT (81.76600 29.92900)          668           6    HUMLA
# ...                            ...          ...         ...      ...
# 1295957  POINT (84.01700 29.27300)          455           4  MUSTANG
# 1295958  POINT (84.04700 29.22900)          455           4  MUSTANG
# 1297070  POINT (83.92600 29.23700)          455           4  MUSTANG
# 1297138  POINT (83.92300 29.20900)          455           4  MUSTANG
# 1305378  POINT (83.83500 29.26200)          455           4  MUSTANG
#
#           GaPa_NaPa     Type_GN Province
# 0            Simkot  Gaunpalika  Karnali
# 651          Simkot  Gaunpalika  Karnali
# 668          Simkot  Gaunpalika  Karnali
# 38137        Simkot  Gaunpalika  Karnali
# 38146        Simkot  Gaunpalika  Karnali
# ...             ...         ...      ...
# 1295957  Lomanthang  Gaunpalika  Gandaki
# 1295958  Lomanthang  Gaunpalika  Gandaki
# 1297070  Lomanthang  Gaunpalika  Gandaki
# 1297138  Lomanthang  Gaunpalika  Gandaki
# 1305378  Lomanthang  Gaunpalika  Gandaki
#
# [1477764 rows x 14 columns]>
